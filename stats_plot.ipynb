# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def plot_hist_with_stats(data, ax, title, bins=90, color='steelblue'):
    sns.histplot(data, bins=bins, ax=ax, color=color, kde=True)
    ax.set_title(title)
    ax.set_xlabel('')
    ax.set_ylabel('Count')

    mean_val = np.mean(data)
    median_val = np.median(data)
    min_val = np.min(data)
    max_val = np.max(data)

    # Draw vertical lines
    ax.axvline(mean_val, color='red', linestyle='--', linewidth=1, label=f'Mean = {mean_val:.3f}')
    ax.axvline(median_val, color='green', linestyle='--', linewidth=1, label=f'Median = {median_val:.3f}')
    ax.axvline(min_val, color='gray', linestyle=':', linewidth=1, label=f'Min = {min_val:.3f}')
    ax.axvline(max_val, color='black', linestyle=':', linewidth=1, label=f'Max = {max_val:.3f}')

    ax.legend(fontsize=8)

# %%
# !uv run src/calculate_stat.py parameters/simulated_scRNASeq_data.tsv parameters/simulated_scRNASeq_data_stats.tsv

stat_file = "simulated_data/simulated_scRNASeq_data_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1. TianKampmann2021_CRISPRi

# %%
# !uv run src/calculate_stat.py data/TianKampmann2021_CRISPRi.h5ad data/TianKampmann2021_CRISPRi_stats.tsv

stat_file = "data/TianKampmann2021_CRISPRi_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Cells, Genes:(32300, 33538) and 1% Cells: 323
# Applying log1p transformation
# Wrote data/TianKampmann2021_CRISPRi_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 323]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. TianKampmann2021_CRISPRa

# %%
# !uv run src/calculate_stat.py data/TianKampmann2021_CRISPRa.h5ad data/TianKampmann2021_CRISPRa_stats.tsv

stat_file = "data/TianKampmann2021_CRISPRa_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Cells, Genes:(21193, 33538) and 1% Cells: 211
# Applying log1p transformation
# Wrote data/TianKampmann2021_CRISPRa_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 211]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. ReplogleWeissman2022_rpe1.h5ad

# %%
# !uv run src/calculate_stat.py data/ReplogleWeissman2022_rpe1.h5ad data/ReplogleWeissman2022_rpe1_stats.tsv

stat_file = "data/ReplogleWeissman2022_rpe1_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Applying log1p transformation
# Wrote data/ReplogleWeissman2022_rpe1_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 100]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. FrangiehIzar2021_protein.h5ad

# %%
# !uv run src/calculate_stat.py data/FrangiehIzar2021_protein.h5ad data/FrangiehIzar2021_protein_stats.tsv

stat_file = "data/FrangiehIzar2021_protein_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Cells, Genes:(218331, 24) and 1% Cells: 2183
# Applying log1p transformation
# Wrote data/FrangiehIzar2021_protein_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 2183]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. NormanWeissman2019_filtered.h5ad

# %%
# !uv run src/calculate_stat.py data/NormanWeissman2019_filtered.h5ad data/NormanWeissman2019_filtered_stats.tsv

stat_file = "data/NormanWeissman2019_filtered_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Cells, Genes:(111445, 33694) and 1% Cells: 1114
# Applying log1p transformation
# Wrote data/NormanWeissman2019_filtered_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 1114]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. AdamsonWeissman2016_GSM2406681_10X010.h5ad

# %%
# !uv run src/calculate_stat.py data/AdamsonWeissman2016_GSM2406681_10X010.h5ad data/AdamsonWeissman2016_GSM2406681_10X010_stats.tsv

stat_file = "data/AdamsonWeissman2016_GSM2406681_10X010_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Cells, Genes:(65337, 32738) and 1% Cells: 653
# Applying log1p transformation
# Wrote data/AdamsonWeissman2016_GSM2406681_10X010_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 653]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. FrangiehIzar2021_RNA.h5ad

# %%
# !uv run src/calculate_stat.py data/FrangiehIzar2021_RNA.h5ad data/FrangiehIzar2021_RNA_stats.tsv

stat_file = "data/FrangiehIzar2021_RNA_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
# Out:
# Wrote data/FrangiehIzar2021_RNA_stats.tsv

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 100]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. ReplogleWeissman2022_K562_essential.h5ad

# %%
# !uv run src/calculate_stat.py data/ReplogleWeissman2022_K562_essential.h5ad data/ReplogleWeissman2022_K562_essential_stats.tsv

stat_file = "data/ReplogleWeissman2022_K562_essential_stats.tsv"

stat_df = pd.read_csv(stat_file, sep="\t", index_col=0)

# Some of the genes have all zero values. So the plot looks weird.
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %%
# Filter out genes with all zero values
filtered_stat_df = stat_df[stat_df['missing_ratio'] < 1.0]
# Alternatively, we can filter out rows where n_nonzero is some threshold, e.g., 100
filtered_stat_df = filtered_stat_df[filtered_stat_df['n_nonzero'] > 100]

fig, axs = plt.subplots(2, 3, figsize=(15, 10))

plot_hist_with_stats(filtered_stat_df['mean_log'], axs[0, 0], 'Mean Distribution')
plot_hist_with_stats(filtered_stat_df['std_log'], axs[0, 1], 'Standard Deviation Distribution')
plot_hist_with_stats(filtered_stat_df['missing_ratio'], axs[0, 2], 'Missing Ratio Distribution')
plot_hist_with_stats(filtered_stat_df['median_log'], axs[1, 0], 'Median Distribution')
plot_hist_with_stats(filtered_stat_df['n_nonzero'], axs[1, 1], 'Non-zero Count Distribution')

# Remove the last empty subplot
fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()
